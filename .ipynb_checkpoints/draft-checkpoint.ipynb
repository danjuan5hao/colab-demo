# %%
# -*- coding: utf-8 -*-
path = "./data/train.txt"
with open(path, "r", encoding="utf-8") as f:
    all_lens = []
    for line in f.readlines():
        rst = line.strip().split("\t")
        label = rst[0]
        text = rst[-1]
        all_lens.append(text)

# %%
all_lens
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
# ...

# %%
import pandas as pd
rst = pd.Series(all_lens)
rst.quantile([0.05,0.5,0.95])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-b88adc9b6250> in <module>
#       1 import pandas as pd
#       2 rst = pd.Series(all_lens)
# ----> 3 rst.quantile([0.05,0.5,0.95])
#
# D:\apps\anaconda3\envs\torch\lib\site-packages\pandas\core\series.py in quantile(self, q, interpolation)
#    2236         df = self.to_frame()
#    2237
# -> 2238         result = df.quantile(q=q, interpolation=interpolation, numeric_only=False)
#    2239         if result.ndim == 2:
#    2240             result = result.iloc[:, 0]
#
# D:\apps\anaconda3\envs\torch\lib\site-packages\pandas\core\frame.py in quantile(self, q, axis, numeric_only, interpolation)
#    9260
#    9261         result = data._mgr.quantile(
# -> 9262             qs=q, axis=1, interpolation=interpolation, transposed=is_transposed
#    9263         )
#    9264
#
# ...
