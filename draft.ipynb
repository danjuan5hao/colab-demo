# %%
# -*- coding: utf-8 -*-
path = "./data/train.txt"
with open(path, "r", encoding="utf-8") as f:
    all_lens = []
    for line in f.readlines():
        rst = line.strip().split("\t")
        label = rst[0]
        text = rst[-1]
        all_lens.append(len(text))

# %%
all_lens
# Out:
# [12,
#  12,
#  18,
#  18,
#  10,
#  11,
#  19,
#  20,
#  11,
#  12,
#  9,
#  21,
#  20,
#  20,
#  16,
#  17,
#  19,
#  15,
#  11,
#  15,
#  13,
#  16,
#  11,
#  14,
#  16,
#  20,
#  15,
#  15,
#  9,
#  17,
#  20,
#  11,
#  15,
#  11,
#  21,
#  22,
#  14,
#  10,
#  12,
#  10,
#  11,
#  16,
#  22,
#  9,
#  16,
#  13,
#  12,
#  20,
#  12,
#  20,
#  15,
#  10,
#  8,
#  17,
#  15,
#  23,
#  20,
#  10,
#  13,
#  21,
#  13,
#  16,
#  13,
#  12,
#  13,
#  16,
#  13,
#  17,
#  15,
#  16,
#  14,
#  19,
#  12,
#  16,
#  12,
#  21,
#  14,
#  14,
#  19,
#  19,
#  11,
#  24,
#  12,
#  20,
#  17,
#  23,
#  17,
#  12,
#  14,
#  14,
#  9,
#  16,
#  10,
#  11,
#  23,
#  12,
#  20,
#  16,
#  20,
#  16,
#  10,
#  12,
#  17,
#  10,
#  9,
#  17,
#  15,
#  9,
#  19,
#  25,
#  14,
#  18,
#  12,
#  12,
#  12,
#  15,
#  19,
#  14,
#  12,
#  18,
#  12,
#  22,
#  20,
#  20,
#  17,
#  21,
#  15,
#  10,
#  11,
#  12,
#  18,
#  20,
#  11,
#  17,
#  19,
#  10,
#  16,
#  14,
#  20,
#  14,
#  14,
#  12,
#  12,
#  22,
#  20,
#  18,
#  20,
#  16,
#  20,
#  12,
#  19,
#  16,
#  9,
#  12,
#  15,
#  15,
#  19,
#  13,
#  13,
#  20,
#  17,
#  14,
#  23,
#  17,
#  14,
#  18,
#  11,
#  14,
#  21,
#  15,
#  20,
#  18,
#  12,
#  10,
#  20,
#  11,
#  22,
#  21,
#  17,
#  23,
#  11,
#  23,
#  11,
#  19,
#  20,
#  18,
#  19,
#  15,
#  8,
#  14,
#  8,
#  7,
#  12,
#  22,
#  14,
#  8,
#  17,
#  16,
#  11,
#  13,
#  14,
#  13,
#  8,
#  9,
#  8,
#  12,
#  16,
#  11,
#  10,
#  13,
#  15,
#  12,
#  24,
#  11,
#  22,
#  21,
#  14,
#  15,
#  15,
#  13,
#  11,
#  15,
#  20,
#  21,
#  14,
#  13,
#  15,
#  18,
#  11,
#  17,
#  12,
#  16,
#  20,
#  15,
#  16,
#  12,
#  11,
#  13,
#  10,
#  20,
#  14,
#  13,
#  15,
#  11,
#  14,
#  17,
#  11,
#  18,
#  15,
#  12,
#  9,
#  11,
#  15,
#  13,
#  22,
#  21,
#  16,
#  13,
#  18,
#  22,
#  19,
#  15,
#  18,
#  12,
#  12,
#  20,
#  12,
#  17,
#  10,
#  18,
#  14,
#  18,
#  15,
#  14,
#  9,
#  12,
#  15,
#  8,
#  22,
#  21,
#  12,
#  8,
#  18,
#  21,
#  12,
#  12,
#  12,
#  6,
#  13,
#  9,
#  14,
#  16,
#  20,
#  14,
#  16,
#  21,
#  16,
#  15,
#  12,
#  10,
#  17,
#  16,
#  11,
#  10,
#  14,
#  16,
#  13,
#  13,
#  16,
#  13,
#  17,
#  16,
#  21,
#  14,
#  15,
#  16,
#  13,
#  21,
#  19,
#  12,
#  19,
#  9,
#  10,
#  23,
#  21,
#  10,
#  10,
#  13,
#  21,
#  10,
#  12,
#  11,
#  14,
#  13,
#  14,
#  15,
#  20,
#  22,
#  10,
#  11,
#  15,
#  13,
#  10,
#  14,
#  12,
#  17,
#  15,
#  16,
#  22,
#  11,
#  10,
#  20,
#  15,
#  14,
#  15,
#  17,
#  17,
#  20,
#  7,
#  13,
#  13,
#  19,
#  14,
#  10,
#  20,
#  18,
#  19,
#  6,
#  12,
#  10,
#  5,
#  11,
#  22,
#  16,
#  15,
#  20,
#  21,
#  17,
#  19,
#  17,
#  16,
#  21,
#  18,
#  12,
#  17,
#  11,
#  22,
#  14,
#  10,
#  13,
#  11,
#  13,
#  16,
#  16,
#  17,
#  10,
#  23,
#  10,
#  16,
#  17,
#  21,
#  11,
#  15,
#  21,
#  20,
#  9,
#  13,
#  9,
#  24,
#  19,
#  25,
#  12,
#  13,
#  12,
#  15,
#  22,
#  19,
#  19,
#  19,
#  14,
#  11,
#  18,
#  15,
#  18,
#  11,
#  17,
#  11,
#  21,
#  12,
#  13,
#  8,
#  10,
#  10,
#  11,
#  21,
#  12,
#  18,
#  22,
#  11,
#  12,
#  20,
#  16,
#  21,
#  11,
#  18,
#  15,
#  16,
#  23,
#  15,
#  12,
#  11,
#  12,
#  12,
#  21,
#  12,
#  10,
#  19,
#  20,
#  18,
#  20,
#  22,
#  24,
#  11,
#  13,
#  14,
#  12,
#  13,
#  11,
#  14,
#  18,
#  12,
#  12,
#  12,
#  11,
#  12,
#  13,
#  15,
#  21,
#  19,
#  12,
#  21,
#  24,
#  18,
#  12,
#  12,
#  20,
#  9,
#  10,
#  13,
#  8,
#  19,
#  19,
#  9,
#  12,
#  8,
#  10,
#  11,
#  12,
#  9,
#  20,
#  8,
#  8,
#  17,
#  14,
#  16,
#  15,
#  12,
#  12,
#  13,
#  23,
#  22,
#  23,
#  15,
#  21,
#  15,
#  19,
#  12,
#  12,
#  14,
#  10,
#  18,
#  17,
#  16,
#  11,
#  20,
#  21,
#  12,
#  22,
#  19,
#  13,
#  22,
#  21,
#  14,
#  13,
#  12,
#  19,
#  22,
#  19,
#  15,
#  10,
#  19,
#  15,
#  14,
#  16,
#  10,
#  13,
#  12,
#  11,
#  20,
#  18,
#  14,
#  9,
#  13,
#  15,
#  14,
#  17,
#  17,
#  11,
#  13,
#  13,
#  11,
#  20,
#  19,
#  25,
#  11,
#  10,
#  22,
#  17,
#  14,
#  21,
#  19,
#  12,
#  17,
#  18,
#  12,
#  20,
#  9,
#  22,
#  11,
#  19,
#  15,
#  19,
#  18,
#  14,
#  17,
#  14,
#  14,
#  14,
#  18,
#  23,
#  10,
#  18,
#  17,
#  12,
#  24,
#  14,
#  18,
#  11,
#  10,
#  15,
#  12,
#  14,
#  10,
#  15,
#  16,
#  12,
#  14,
#  15,
#  16,
#  14,
#  17,
#  9,
#  17,
#  15,
#  10,
#  16,
#  23,
#  11,
#  19,
#  18,
#  14,
#  11,
#  10,
#  12,
#  22,
#  18,
#  9,
#  9,
#  13,
#  9,
#  9,
#  20,
#  10,
#  10,
#  14,
#  20,
#  15,
#  15,
#  12,
#  16,
#  22,
#  17,
#  13,
#  11,
#  11,
#  20,
#  14,
#  12,
#  21,
#  12,
#  20,
#  15,
#  19,
#  14,
#  9,
#  21,
#  15,
#  12,
#  13,
#  9,
#  10,
#  9,
#  10,
#  15,
#  8,
#  18,
#  14,
#  20,
#  22,
#  12,
#  22,
#  11,
#  18,
#  19,
#  22,
#  11,
#  21,
#  22,
#  17,
#  20,
#  23,
#  13,
#  12,
#  18,
#  15,
#  14,
#  12,
#  15,
#  24,
#  12,
#  12,
#  13,
#  17,
#  9,
#  10,
#  10,
#  19,
#  13,
#  18,
#  10,
#  20,
#  13,
#  10,
#  8,
#  19,
#  12,
#  11,
#  10,
#  11,
#  14,
#  11,
#  21,
#  20,
#  16,
#  9,
#  20,
#  11,
#  16,
#  10,
#  10,
#  18,
#  17,
#  21,
#  13,
#  8,
#  12,
#  17,
#  15,
#  24,
#  18,
#  12,
#  21,
#  13,
#  13,
#  9,
#  20,
#  10,
#  16,
#  12,
#  16,
#  10,
#  16,
#  12,
#  13,
#  12,
#  21,
#  19,
#  17,
#  20,
#  9,
#  12,
#  10,
#  22,
#  20,
#  13,
#  14,
#  20,
#  15,
#  11,
#  14,
#  11,
#  13,
#  17,
#  15,
#  18,
#  13,
#  10,
#  19,
#  16,
#  16,
#  12,
#  10,
#  15,
#  13,
#  18,
#  22,
#  21,
#  17,
#  15,
#  24,
#  14,
#  13,
#  18,
#  17,
#  10,
#  12,
#  14,
#  18,
#  14,
#  16,
#  8,
#  13,
#  15,
#  22,
#  17,
#  17,
#  17,
#  17,
#  19,
#  20,
#  20,
#  15,
#  9,
#  17,
#  15,
#  16,
#  15,
#  17,
#  14,
#  22,
#  24,
#  21,
#  10,
#  11,
#  16,
#  14,
#  11,
#  19,
#  16,
#  13,
#  10,
#  16,
#  16,
#  15,
#  18,
#  12,
#  15,
#  16,
#  18,
#  19,
#  22,
#  14,
#  17,
#  20,
#  18,
#  24,
#  20,
#  13,
#  19,
#  21,
#  19,
#  12,
#  16,
#  19,
#  16,
#  12,
#  19,
#  18,
#  13,
#  23,
#  18,
#  10,
#  21,
#  16,
#  21,
#  18,
#  17,
#  17,
#  21,
#  19,
#  16,
#  14,
#  13,
#  9,
#  15,
#  13,
#  12,
#  10,
#  21,
#  17,
#  18,
#  18,
#  14,
#  17,
#  16,
#  18,
#  14,
#  23,
#  11,
#  12,
#  8,
#  21,
#  11,
#  18,
#  14,
#  13,
#  15,
#  8,
#  14,
#  18,
#  22,
#  12,
#  21,
#  16,
#  20,
#  21,
#  21,
#  22,
#  15,
#  13,
#  12,
#  12,
#  19,
#  10,
#  10,
#  16,
#  14,
#  7,
#  12,
#  9,
#  10,
#  10,
#  11,
#  15,
#  17,
#  11,
#  20,
#  15,
#  12,
#  14,
#  20,
#  17,
#  14,
#  13,
#  19,
#  23,
#  14,
#  10,
#  10,
#  12,
#  10,
#  14,
#  13,
#  12,
#  10,
#  14,
#  8,
#  11,
#  20,
#  26,
#  21,
#  20,
#  15,
#  13,
#  13,
#  13,
#  22,
#  15,
#  21,
#  11,
#  17,
#  11,
#  17,
#  11,
#  20,
#  12,
#  14,
#  12,
#  21,
#  10,
#  13,
#  20,
#  20,
#  22,
#  21,
#  12,
#  12,
#  12,
#  9,
#  20,
#  16,
#  13,
#  17,
#  20,
#  13,
#  18,
#  22,
#  17,
#  18,
#  23,
#  14,
#  12,
#  21,
#  12,
#  12,
#  15,
#  12,
#  13,
#  22,
#  13,
#  13,
#  14,
#  12,
#  11,
#  18,
#  10,
#  13,
#  11,
#  15,
#  16,
#  ...]

# %%
import pandas as pd
rst = pd.Series(all_lens)
rst.quantile([0.05,0.5,0.95])
# Out:
# 0.05    12.0
# 0.50    20.0
# 0.95    25.0
# dtype: float64

# %%
from gensim.models.keyedvectors import load_word2vec_format
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-17-2431901ffb06> in <module>
# ----> 1 from gensim.models.keyedvectors import load_word2vec_format
#
# ImportError: cannot import name 'load_word2vec_format' from 'gensim.models.keyedvectors' (D:\apps\anaconda3\envs\torch\lib\site-packages\gensim\models\keyedvectors.py)
